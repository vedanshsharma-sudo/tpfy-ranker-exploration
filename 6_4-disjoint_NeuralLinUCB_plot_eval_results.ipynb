# %%
import pandas as pd
from datetime import date, timedelta
import seaborn as sns
import matplotlib.pyplot as plt

date = '2026-02-09'
checkpoint = '1770723470'
path = f'disjoint_neural_linucb/disjoined_neural_linUCB_offline_matrices_{date}_{checkpoint}/validation_dumping_dict_{date}/validation_metrics/valid_metrics_{date}'
valid_dict = pd.read_pickle(path)

# %%
A = pd.read_pickle(f'disjoint_neural_linucb/disjoined_neural_linUCB_offline_matrices_2026-02-09_1770723470/arm_index_39000.pkl')

# %%
len(A)
# Out:
# 8343

# %%
valid_dict
# Out:
# {'unique_users': 47233,
#  'deepFM_params': [-0.7051282246907552, 0.8711228229877475],
#  'variances_params': [0.11639537811279296, 0.07741446887284482],
#  'deepFM_valid_results': {'ndcg_results': {'NDCG@1': 0.3697190514300156,
#    'NDCG@3': 0.493156184644393,
#    'NDCG@5': 0.6090509044532811},
#   'popularity_dist_dict': {'Popularity distribution @ 1': {'High': 11.3,
#     'Low': 30.89,
#     'Medium': 36.93,
#     'Negligible': 9.57,
#     'Unmapped': 0.7,
#     'Weekly New Releases': 10.6},
#    'Popularity distribution @ 3': {'High': 8.36,
#     'Low': 36.36,
#     'Medium': 39.61,
#     'Negligible': 9.65,
#     'Unmapped': 0.58,
#     'Weekly New Releases': 5.44},
#    'Popularity distribution @ 5': {'High': 6.83,
#     'Low': 39.65,
#     'Medium': 38.71,
#     'Negligible': 10.3,
#     'Unmapped': 0.53,
#     'Weekly New Releases': 3.98}},
#   'catalog_dict': {'Catalog Length @ 1': 3623,
#    'Catalog Length @ 3': 5181,
#    'Catalog Length @ 5': 5911},
# ...
